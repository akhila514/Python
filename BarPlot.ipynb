# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
family_mem = [6,10,2,4,3]
fam_name = ('A','B','C','D','E')
plt.bar(fam_name,family_mem)
plt.title("BAR Chart")
plt.xlabel("Family Name")
plt.ylabel("Family Count")
#plt.xticks(fam_name,family_mem)
# Out:
# Text(0, 0.5, 'Family Count')

# %%
plt.title("Horizontal BarChart")
plt.barh(fam_name,family_mem)
# Out:
# <BarContainer object of 5 artists>

# %%
#coloring
plt.bar(fam_name,family_mem,align='center',color='green')
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(fam_name,family_mem,align='center',color=(0.2,0.4,0.6,0.6))
# Out:
# <BarContainer object of 5 artists>

# %%
#edge color and differnet colors
plt.bar(fam_name,family_mem,align='center',color=['greenyellow','lightblue','lightgreen','purple','cyan'],edgecolor = 'red')
# Out:
# <BarContainer object of 5 artists>

# %%
#space between bars
x = ['python','c++','.Net','R','HTML']
y = [1000,600,620,700,800]
bar_pos = [1,3,7,9,11]
plt.bar(bar_pos,y)
plt.xticks(bar_pos,x)
# Out:
# ([<matplotlib.axis.XTick at 0x3c9f2b5d30>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#width of bar
width= [3,0.55,0.3,0.1,0.7]
plt.bar(bar_pos,y,width=width)
plt.xticks(bar_pos,x)
# Out:
# ([<matplotlib.axis.XTick at 0x3c9f445cf8>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
#styling
x = ['python','c++','.Net','R','HTML']
y = [1000,600,620,700,800]
bar_pos = np.arange(len(x))
plt.bar(bar_pos,y)
plt.xticks(bar_pos,x,color = 'purple')
plt.yticks(color='green')
plt.xlabel("CourseName",fontweight='bold',fontsize=16,color='orange')
# Out:
# Text(0.5, 0, 'CourseName')

# %%
#Increase bottom margin
x = ['python-coursename1','c++-coursename2','.Net-coursename3','R-coursename4','HTML-coursename5']
y = [1000,600,620,700,800]
bar_pos = [1,3,7,9,11]
plt.bar(bar_pos,y)
plt.xticks(bar_pos,x,rotation=90,fontweight='bold')
# Out:
# ([<matplotlib.axis.XTick at 0x3c9f4b4d68>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
x1 = ['A','B','C','D']
y1 = [10,30,11,25]
x2=['w','x','y','z']
y2=[15,100,55,195]
plt.bar(x1,y1)
plt.bar(x2,y2)
plt.legend(labels=['blue','orange'])

# %%
barWidth = 0.9
bars1 = [3, 3, 1]
bars2 = [4, 2, 3]
bars3 = [4, 6, 7, 10, 4, 4]
bars4 = bars1 + bars2 + bars3
 
r1 = [1,5,9]
r2 = [2,6,10]
r3 = [3,4,7,8,11,12]
r4 = r1 + r2 + r3

plt.bar(r1, bars1, width = barWidth, color = (0.3,0.1,0.4,0.6), label='Alone')
plt.bar(r2, bars2, width = barWidth, color = (0.3,0.5,0.4,0.6), label='With Himself')
plt.bar(r3, bars3, width = barWidth, color = (0.3,0.9,0.4,0.6), label='With other genotype')

 

plt.legend()
 
# Text below each barplot with a rotation at 90°
plt.xticks([r + barWidth for r in range(len(r4))], ['DD', 'with himself', 'with DC', 'with Silur', 'DC', 'with himself', 'with DD', 'with Silur', 'Silur', 'with himself', 'with DD', 'with DC'], rotation=90)
 
# Create labels
label = ['n = 6', 'n = 25', 'n = 13', 'n = 36', 'n = 30', 'n = 11', 'n = 16', 'n = 37', 'n = 14', 'n = 4', 'n = 31', 'n = 34']
 
# Text on the top of each barplot
for i in range(len(r4)):
    plt.text(x = r4[i]-0.5 , y = bars4[i]+0.1, s = label[i], size = 6)
 
# Adjust the margins
plt.subplots_adjust(bottom= 0.2, top = 0.98)
 
# Show graphic
plt.show()
